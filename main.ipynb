# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load dataset
df = pd.read_csv("perfume.csv")
df.head()
# Out:
#            brand                                  instagram_link  followers  \
# 0      Alchemist  https://www.instagram.com/alchemist.fragrance/      17800
# 1  Alien Objects         https://www.instagram.com/alienobjects/      15700
# 2  ALT Perfumery        https://www.instagram.com/alt.perfumery/       6528
# 3      Ara Scent            https://www.instagram.com/ara.scent/        119
# 4         Aromes            https://www.instagram.com/aromes.id/      15700
#
#    year          variant                                       variant_link  \
# 0  2022      Powder Room  https://shopee.co.id/alchemist.fragrance/17137...
# 1  2019             XOXO      https://shopee.co.id/alienobjects/14283008217
# 2  2021  Moroccan Sunset      https://shopee.co.id/altperfumery/12639590547
# 3  2023            Sogno         https://shopee.co.id/ara.scent/22247002537
# 4  2022       Crazy Sexy         https://shopee.co.id/aromes.id/19521086160
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   brand           120 non-null    object
#  1   instagram_link  120 non-null    object
#  2   followers       120 non-null    int64
#  3   year            120 non-null    int64
#  4   variant         120 non-null    object
#  5   variant_link    120 non-null    object
#  6   concentration   120 non-null    object
#  7   size            120 non-null    int64
#  8   price           120 non-null    object
#  9   price_per_ml    120 non-null    object
#  10  top_notes1      120 non-null    object
#  11  top_notes2      111 non-null    object
#  12  top_notes3      79 non-null     object
#  13  top_notes4      30 non-null     object
#  14  top_notes5      13 non-null     object
#  15  top_notes6      7 non-null      object
#  16  mid_notes1      110 non-null    object
# ...

# %%
# drop duplicate data
duplicate = df[df.duplicated()]
print(duplicate.shape)

df = df.drop_duplicates()
# Out:
# (0, 35)

# %%
df.count()
# Out:
# brand             120
# instagram_link    120
# followers         120
# year              120
# variant           120
# variant_link      120
# concentration     120
# size              120
# price             120
# price_per_ml      120
# top_notes1        120
# top_notes2        111
# top_notes3         79
# top_notes4         30
# top_notes5         13
# top_notes6          7
# mid_notes1        110
# mid_notes2        100
# mid_notes3         70
# mid_notes4         26
# mid_notes5         11
# mid_notes6          4
# mid_notes7          3
# Unnamed: 23         1
# Unnamed: 24         1
# base_notes1       104
# base_notes2        97
# base_notes3        70
# base_notes4        33
# base_notes5        14
# base_notes6         9
# Unnamed: 31         1
# Unnamed: 32         1
# Unnamed: 33         1
# base_notes7         4
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# brand               0
# instagram_link      0
# followers           0
# year                0
# variant             0
# variant_link        0
# concentration       0
# size                0
# price               0
# price_per_ml        0
# top_notes1          0
# top_notes2          9
# top_notes3         41
# top_notes4         90
# top_notes5        107
# top_notes6        113
# mid_notes1         10
# mid_notes2         20
# mid_notes3         50
# mid_notes4         94
# mid_notes5        109
# mid_notes6        116
# mid_notes7        117
# Unnamed: 23       119
# Unnamed: 24       119
# base_notes1        16
# base_notes2        23
# base_notes3        50
# base_notes4        87
# base_notes5       106
# base_notes6       111
# Unnamed: 31       119
# Unnamed: 32       119
# Unnamed: 33       119
# base_notes7       116
# dtype: int64

# %%
# display the data(barplot)
new_df = df.head(20)
plt.bar(new_df["brand"], new_df["followers"], color="red", width=0.5)
plt.xlabel("Indonesian Perfume Brand")
plt.ylabel("Followers")
plt.title("Followers data on Indonesian perfume brands")
plt.xticks(rotation=45)
plt.show()

# %%
new_df = df.head(10)
plt.pie(new_df["followers"], labels=new_df["brand"])
# Out:
# ([<matplotlib.patches.Wedge at 0x1caeecaf110>,
# ...
#  [Text(0.7504864057354173, 0.8042202153678648, 'Alchemist'),
#   Text(-0.7831732626984168, 0.7724245209690827, 'Alien Objects'),
#   Text(-1.067035930008257, -0.2672720039050374, 'ALT Perfumery'),
#   Text(-0.9368436018609547, -0.576475555121111, 'Ara Scent'),
#   Text(-0.31505568259982225, -1.053916465789182, 'Aromes'),
#   Text(0.5219183127825768, -0.9682981332121778, 'Astree'),
#   Text(0.8787395509813253, -0.6616772638840926, 'Ataraksia'),
#   Text(1.0718133957518665, -0.24741876381320158, 'Ataraxia'),
#   Text(1.0914401057002971, -0.13696165765981594, 'avantglossy'),
#   Text(1.0992882138545443, -0.03956542531663336, 'Avicenna')])

# %%
# displaying with scatter plot
new_df=df.head(20)
plt.scatter(new_df["followers"], new_df["price_per_ml"])
plt.xlabel("Followers")
plt.ylabel("Price per ML")
plt.title("Scatter plot of Followers vs Price per ML")
plt.show()

# %%
# showing outlier
outl = plt.figure(figsize=(12,4))
outl.add_subplot(1,2,1)
df["followers"].plot(kind="area")
outl.add_subplot(1,2,2,)
plt.boxplot(df["followers"])
plt.show()
